# %% [markdown]
# <a href="https://colab.research.google.com/github/yoshi-karino/Spoon-Knife/blob/main/vscode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
#test test
# Out:
# Mounted at /content/drive

# %%
# !pip install colab_ssh --upgrade

#from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
#launch_ssh_cloudflared(password="Mifushiy@")

from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password='Mifushiy@')
# Out:
# ...
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %%
# !ls -l
# Out:
# total 35636
# -rwxr-xr-x 1 root root 36477489 Oct 31 12:37 cloudflared
# -rw-r--r-- 1 root root     2618 Nov 16 23:25 cloudflared.log
# drwx------ 6 root root     4096 Nov 16 23:24 drive
# drwxr-xr-x 1 root root     4096 Nov 15 14:30 sample_data

# %%
import pandas as pd

df = pd.DataFrame({
    'name'    : ['Alice', 'Bob', 'Charlie', 'Charlie', 'Alice', 'Bob'],
    'item' : ['aaa', 'bbb', 'ccc', 'ddd', 'eee', 'fff'],
    'number'    : [3, 2, 4, 3, 2, 1],
})

prev = pd.DataFrame({
    'camry'    : ['Alice', 'Bob', 'Charlie', 'Charlie', 'Alice', 'Bob'],
    'metz' : ['aaa', 'bbb', 'ccc', 'ddd', 'eee', 'fff'],
    'number'    : [3, 2, 4, 3, 2, 1],
})

#prev 内で df にはない列
#a = set(prev.columns) - set(df.columns)
a = set(prev) - set(df)
b = set(prev.columns) - set(df.columns)

df3 = [('tel', ['3333', '222', '111'])]
df4 = {'tel', '3333'}


df5 = pd.DataFrame({'tel' : ['3333']})
df6 = pd.DataFrame({'name' : ['Alice', 'Bob', 'Charlie', 'Charlie', 'Alice', 'Bob', 'Alice', 'Bob']})
#for f1, f2 in df3:
#  display(f1, f2)

PREVIOUS_APPLICATION_AGGREGATION_RECIPIES = []
for agg in ['mean', 'min', 'max', 'sum', 'var']:
    for select in ['AMT_ANNUITY',
                   'AMT_APPLICATION'
                   ]:
        PREVIOUS_APPLICATION_AGGREGATION_RECIPIES.append((select, agg))
PREVIOUS_APPLICATION_AGGREGATION_RECIPIES = [(['SK_ID_CURR'], PREVIOUS_APPLICATION_AGGREGATION_RECIPIES)]

display(PREVIOUS_APPLICATION_AGGREGATION_RECIPIES [0])
# Out:
# (['SK_ID_CURR'],
#  [('AMT_ANNUITY', 'mean'),
#   ('AMT_APPLICATION', 'mean'),
#   ('AMT_ANNUITY', 'min'),
#   ('AMT_APPLICATION', 'min'),
#   ('AMT_ANNUITY', 'max'),
#   ('AMT_APPLICATION', 'max'),
#   ('AMT_ANNUITY', 'sum'),
#   ('AMT_APPLICATION', 'sum'),
#   ('AMT_ANNUITY', 'var'),
#   ('AMT_APPLICATION', 'var')])

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({
    'name'     : ['Alice', 'Bob', 'Charlie', 'Charlie', 'Alice', 'Bob', 'Alice', 'Bob'],
    'gender'    : ['F', 'M', 'M', 'M', 'M', 'M','F','F',],
    'item'      : ['aaa', 'bbb', 'ccc', 'ddd', 'aaa', 'fff','bbb', 'ccc'],
    'number1'  : [3, 2, 4, 3, 2, 1, 4,3],
    'number2'  : [15, 8, 24, 38, 20, 1, 30,40],
})

df2 = pd.DataFrame({
    'name'     : ['Alice', 'Bob', 'Charlie2', 'Charlie', 'Alice', 'Bob', 'Alice', 'Bob'],
    'gender'    : ['FFF', 'M', 'M', 'M', 'M', 'M','F','F',],
    'item'      : ['aaa', 'bbb', 'ccc', 'ddd', 'aaa', 'fff','bbb', 'ccc'],
    'number1'  : [3, 2, 4, 3, 2, 1, 4,300],
    'number2'  : [15, 8, 24, 38, 20, 1, 30,40],
})

diffcomp = df1.compare(df2)
display(diffcomp)
display(diffcomp.columns.droplevel(1).unique())
display(diffcomp.number1.dropna())
# Out:
#       name           gender       number1
#       self     other   self other    self  other
# 0      NaN       NaN      F   FFF     NaN    NaN
# 2  Charlie  Charlie2    NaN   NaN     NaN    NaN
# 7      NaN       NaN    NaN   NaN     3.0  300.0
# Index(['name', 'gender', 'number1'], dtype='object')
#    self  other
# 7   3.0  300.0
